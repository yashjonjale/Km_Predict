# %%
# !pip install umap-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 8.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 8.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import umap

# Load the Iris dataset
data = load_iris()
X = data.data
y = data.target

# Initialize UMAP
reducer = umap.UMAP(n_components=2, random_state=42)

# Fit and transform the data
X_umap = reducer.fit_transform(X)

# Plot the results
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_umap[:, 0], X_umap[:, 1], c=y, cmap='viridis')
plt.colorbar(scatter, label='Target Class')
plt.title('UMAP Visualization of Iris Dataset')
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
plt.show()
# Out:
# /home/yashjonjale/.local/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris

# Load the Iris dataset
data = load_iris()
X = data.data
y = data.target

# Initialize t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)

# Measure the time taken for t-SNE
start_time = time.time()
X_tsne = tsne.fit_transform(X)
end_time = time.time()

# Print the running time
print(f"t-SNE computation took {end_time - start_time:.2f} seconds")

# Plot the results
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.colorbar(scatter, label='Target Class')
plt.title('t-SNE Visualization of Iris Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
# plt.show()

#make it more interactive
import plotly.express as px
import pandas as pd

X = X_tsne
y = y
# Out:
# t-SNE computation took 0.87 seconds

# %%
# do not make a scatter plot

# make a surface plot, explain what is a surface plot
# a surface plot is a 3D plot that shows the relationship between three variables.
# It is useful for visualizing the relationship between three continuous variables.
# In this case, we are using the t-SNE components as the x and y coordinates, and the target class as the z coordinate.
# how is it different from a scatter plot
# A scatter plot is a 2D plot that shows the relationship between two variables.
# A surface plot is a 3D plot that shows the relationship between three variables.
# A scatter plot is useful for visualizing the relationship between two continuous variables, while a surface plot is useful for visualizing the relationship between three continuous variables.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_334896/3575153818.py in <module>
#       1 #plot X and y as a surface plot
# ----> 2 fig = px.scatter_3d(x=X[:, 0], y=X[:, 1], z=X[:, 2], color=y)
#       3 fig.update_layout(scene = dict(
#       4                     xaxis_title='t-SNE Component 1',
#       5                     yaxis_title='t-SNE Component 2',
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
path = "/home/yashjonjale/Documents/intern_proj/Model/Dataset/final_data.npz"
import numpy as np
import matplotlib.pyplot as plt
#load numpy array
data = np.load(path)

# %%
data = data['arr_0']
n = 5000
esm = data[:n, 3:1280+3]
esm1 = data[:n, 1283:1280+1283]
delta = data[:n,2]
wild = data[:n,1]

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris

# Load the Iris dataset
# data = load_iris()
X = esm+esm1
y = wild+delta

# Initialize t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)

# Measure the time taken for t-SNE
start_time = time.time()
X_tsne = tsne.fit_transform(X)
end_time = time.time()

# Print the running time
print(f"t-SNE computation took {end_time - start_time:.2f} seconds")
print(len(X_tsne))


# Plot the results for
# Out:
# t-SNE computation took 21.68 seconds
# 5000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_329630/937394295.py in <module>
#      26 from mpld3 import plugins
#      27
# ---> 28 fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
#      29 labels = y - wild
#      30
#
# ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1701     """
#    1702     fig = figure(**fig_kw)
# -> 1703     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1704                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1705                        gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#
# ...

# %%
mpld3.enable_notebook()
from mpld3 import plugins

# %%
fig, ax = plt.subplots(figsize=(10, 8))
scatter = ax.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')

# Add labels and title
ax.set_title('t-SNE Visualization of Iris Dataset with Continuous Values')
ax.set_xlabel('t-SNE Component 1')
ax.set_ylabel('t-SNE Component 2')

# Add a color bar
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Continuous Value')

# Add zoom and pan interaction
plugins.connect(fig, plugins.Zoom(), plugins.BoxZoom(), plugins.Reset())

# Display the plot
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el3296301292730146936169752429899"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...
