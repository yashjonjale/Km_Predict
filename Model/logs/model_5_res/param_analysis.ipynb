# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
import glob
import os

pattern = "/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_*"

#find files with the pattern in the directory and sort them by creation time
files = glob.glob(pattern)
files.sort(key=os.path.getmtime)

# %%
len(files)
# Out:
# 10

# %%
print(files)
# Out:
# ['/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-26 15:43:47.746074.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-26 16:03:54.015918.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-26 16:31:58.809558.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-26 17:58:26.395364.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-26 19:29:35.858130.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-27 02:35:06.281176.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-27 08:04:24.718841.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-27 12:49:37.724146.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-27 17:08:55.377006.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/model_5_res/best_params_0.8_size_2024-06-27 21:33:47.453285.json']

# %%
df = []
for file in files:
    with open(file) as f:
        data = json.load(f)
        df.append(data)

# %%
df
# Out:
# [{'learning_rate': 0.22337792377334018,
#   'max_delta_step': 0.10618019423583702,
#   'max_depth': 9.0,
#   'min_child_weight': 7.6371409668806285,
#   'num_rounds': 162.773212698597,
#   'reg_alpha': 4.2297252804720245,
#   'reg_lambda': 2.7538710646513924},
#  {'learning_rate': 0.256143444729838,
#   'max_delta_step': 0.6592926226521201,
#   'max_depth': 9.0,
#   'min_child_weight': 12.495089237370328,
#   'num_rounds': 34.33335719640287,
#   'reg_alpha': 3.608547458367956,
#   'reg_lambda': 1.5769162058540942},
#  {'learning_rate': 0.18621812428387807,
#   'max_delta_step': 1.479606043000834,
#   'max_depth': 8.0,
#   'min_child_weight': 13.943657199377599,
#   'num_rounds': 94.36048666611225,
#   'reg_alpha': 1.5639305386118068,
#   'reg_lambda': 3.480139205573645},
#  {'learning_rate': 0.11092825847835656,
#   'max_delta_step': 3.4527981818396523,
#   'max_depth': 8.0,
#   'min_child_weight': 8.012126196403175,
#   'num_rounds': 125.6714653333354,
#   'reg_alpha': 3.713609489342806,
#   'reg_lambda': 3.650139737233402},
#  {'learning_rate': 0.16880031959504196,
#   'max_delta_step': 4.327300781577501,
#   'max_depth': 7.0,
#   'min_child_weight': 5.02875013986931,
#   'num_rounds': 158.74552669313465,
#   'reg_alpha': 0.30300650059702894,
#   'reg_lambda': 4.977504926636425},
#  {'learning_rate': 0.1960476469738084,
#   'max_delta_step': 4.061969880573671,
#   'max_depth': 6.0,
#   'min_child_weight': 0.11780233987320068,
#   'num_rounds': 198.18215679845127,
#   'reg_alpha': 1.2654730164882866,
#   'reg_lambda': 0.18980228947743316},
#  {'learning_rate': 0.1816237630640138,
#   'max_delta_step': 3.7075272838284374,
#   'max_depth': 7.0,
#   'min_child_weight': 14.467343729677578,
#   'num_rounds': 122.96584854429837,
#   'reg_alpha': 1.664613298568448,
#   'reg_lambda': 3.763734085270521},
#  {'learning_rate': 0.1313650876048921,
#   'max_delta_step': 2.4500140810528888,
#   'max_depth': 7.0,
#   'min_child_weight': 1.0230954272222617,
#   'num_rounds': 159.42552757909513,
#   'reg_alpha': 4.107182581279286,
#   'reg_lambda': 3.883297209157383},
#  {'learning_rate': 0.16573718016564296,
#   'max_delta_step': 3.4615246359941865,
#   'max_depth': 7.0,
#   'min_child_weight': 8.13482536918094,
#   'num_rounds': 164.6579652520223,
#   'reg_alpha': 0.5487502191137478,
#   'reg_lambda': 3.5679109028372946},
#  {'learning_rate': 0.14272124197567235,
#   'max_delta_step': 3.731559611806397,
#   'max_depth': 8.0,
#   'min_child_weight': 6.256373582954971,
#   'num_rounds': 137.74637456148233,
#   'reg_alpha': 2.0781287434418405,
#   'reg_lambda': 3.7925852889976603}]

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#    learning_rate  max_delta_step  max_depth  min_child_weight  num_rounds  \
# 0       0.223378        0.106180        9.0          7.637141  162.773213
# 1       0.256143        0.659293        9.0         12.495089   34.333357
# 2       0.186218        1.479606        8.0         13.943657   94.360487
# 3       0.110928        3.452798        8.0          8.012126  125.671465
# 4       0.168800        4.327301        7.0          5.028750  158.745527
# 5       0.196048        4.061970        6.0          0.117802  198.182157
# 6       0.181624        3.707527        7.0         14.467344  122.965849
# 7       0.131365        2.450014        7.0          1.023095  159.425528
# 8       0.165737        3.461525        7.0          8.134825  164.657965
# 9       0.142721        3.731560        8.0          6.256374  137.746375
#
#    reg_alpha  reg_lambda
# 0   4.229725    2.753871
# 1   3.608547    1.576916
# 2   1.563931    3.480139
# 3   3.713609    3.650140
# 4   0.303007    4.977505
# 5   1.265473    0.189802
# 6   1.664613    3.763734
# 7   4.107183    3.883297
# 8   0.548750    3.567911
# 9   2.078129    3.792585

# %%
#find the mean, median and std of the columns
df.describe()
# Out:
#        learning_rate  max_delta_step  max_depth  min_child_weight  num_rounds  \
# count      10.000000       10.000000  10.000000         10.000000   10.000000
# mean        0.176296        2.743777   7.600000          7.711620  135.886192
# std         0.043071        1.496440   0.966092          4.936852   45.728987
# min         0.110928        0.106180   6.000000          0.117802   34.333357
# 25%         0.148475        1.722208   7.000000          5.335656  123.642253
# 50%         0.175212        3.457161   7.500000          7.824634  148.245951
# 75%         0.193590        3.725552   8.000000         11.405023  161.936291
# max         0.256143        4.327301   9.000000         14.467344  198.182157
#
#        reg_alpha  reg_lambda
# count  10.000000   10.000000
# mean    2.308297    3.163590
# std     1.483970    1.357829
# min     0.303007    0.189802
# 25%     1.340087    2.935438
# 50%     1.871371    3.609025
# 75%     3.687344    3.785372
# max     4.229725    4.977505

# %%
# 0.1 to 0.2
# 1.2 to 3.9
# 7 to 9
# 3 to 12
# 100 to 180
# 0 to 3
# 3 to 4
