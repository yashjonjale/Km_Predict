# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
import glob
import os

pattern = "/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_*"
#find files with the pattern in the directory and sort them by creation time
files = glob.glob(pattern)
files.sort(key=os.path.getmtime)

# %%
len(files)
# Out:
# 8

# %%
print(files)
# Out:
# ['/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_100_0.8_size_2024-07-01 20:00:17.912397.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_10_0.8_size_2024-07-01 16:49:53.474303.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_150_0.8_size_2024-07-01 21:34:02.087498.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_200_0.8_size_2024-07-01 23:24:14.785135.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_20_0.8_size_2024-07-01 17:16:42.723127.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_40_0.8_size_2024-07-01 17:46:57.019695.json', '/home/yashjonjale/Documents/intern_proj/Model/logs/clsfr_res/models/best_params_classification_50_0.8_size_2024-07-01 18:22:08.217275.json', 
# ...

# %%
df = []
for file in files:
    with open(file) as f:
        data = json.load(f)
        df.append(data)

# %%
df
# Out:
# [{'colsample_bytree': 0.510308763550267,
#   'gamma': 1.1093995943280577,
#   'learning_rate': 0.04,
#   'max_depth': 6.0,
#   'min_child_weight': 0.0,
#   'n_estimators': 966.0,
#   'reg_alpha': 5.759179974756401,
#   'reg_lambda': 0.2235359459613454,
#   'rounds': 70.0},
#  {'colsample_bytree': 0.6644222837394447,
#   'gamma': 0.7723717018404136,
#   'learning_rate': 0.24,
#   'max_depth': 3.0,
#   'min_child_weight': 7.0,
#   'n_estimators': 843.0,
#   'reg_alpha': 6.908781114752512,
#   'reg_lambda': 0.3317131895569566,
#   'rounds': 90.0},
#  {'colsample_bytree': 0.6655834275990422,
#   'gamma': 0.26781227962960796,
#   'learning_rate': 0.08,
#   'max_depth': 7.0,
#   'min_child_weight': 9.0,
#   'n_estimators': 564.0,
#   'reg_alpha': 0.6729017164065372,
#   'reg_lambda': 0.09309686506871928,
#   'rounds': 60.0},
#  {'colsample_bytree': 0.9858316713020505,
#   'gamma': 0.613000973198345,
#   'learning_rate': 0.15,
#   'max_depth': 5.0,
#   'min_child_weight': 10.0,
# ...

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#    colsample_bytree     gamma  learning_rate  max_depth  min_child_weight  \
# 0          0.510309  1.109400           0.04        6.0               0.0
# 1          0.664422  0.772372           0.24        3.0               7.0
# 2          0.665583  0.267812           0.08        7.0               9.0
# 3          0.985832  0.613001           0.15        5.0              10.0
# 4          0.537074  1.512836           0.02        6.0               7.0
# 5          0.520624  0.734747           0.12        5.0               4.0
# 6          0.907685  0.255521           0.04        9.0               8.0
# 7          0.863220  4.217904           0.01        7.0               8.0
#
#    n_estimators  reg_alpha  reg_lambda  rounds
# 0         966.0   5.759180    0.223536    70.0
# 1         843.0   6.908781    0.331713    90.0
# 2         564.0   0.672902    0.093097    60.0
# 3         774.0   3.026199    0.630681    90.0
# 4         887.0   1.603698    0.817507    50.0
# ...

# %%
#find the mean, median and std of the columns
df.describe()
# Out:
#        colsample_bytree     gamma  learning_rate  max_depth  min_child_weight  \
# count          8.000000  8.000000       8.000000   8.000000           8.00000
# mean           0.706844  1.185449       0.087500   6.000000           6.62500
# std            0.188321  1.293778       0.078695   1.772811           3.20435
# min            0.510309  0.255521       0.010000   3.000000           0.00000
# 25%            0.532962  0.526704       0.035000   5.000000           6.25000
# 50%            0.665003  0.753559       0.060000   6.000000           7.50000
# 75%            0.874336  1.210259       0.127500   7.000000           8.25000
# max            0.985832  4.217904       0.240000   9.000000          10.00000
#
#        n_estimators  reg_alpha  reg_lambda     rounds
# count      8.000000   8.000000    8.000000    8.00000
# mean     775.750000   4.413360    0.400357   72.50000
# std      171.691376   3.105436    0.288128   19.08627
# ...

# %%
# 0.1 to 0.2
# 1.2 to 3.9
# 7 to 9
# 3 to 12
# 100 to 180
# 0 to 3
# 3 to 4
